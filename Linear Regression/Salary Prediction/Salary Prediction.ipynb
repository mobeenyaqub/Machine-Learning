# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.shape
# Out:
# (30, 3)

# %%
x = np.array(df.YearsExperience).reshape(-1, 1)
y = np.array(df.Salary)

# %%
model = linear_model.LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y, color="red")
plt.plot(x, model.predict(x), color="blue")

# %%
years = float(input("Enter years of experience to predict salary: "))
predicted_salary = model.predict([[years]])
f"Predicted salary for {years} years of experience: {predicted_salary[0]:.0f}"
# Out:
# 'Predicted salary for 10.0 years of experience: 119348'

# %%
plt.scatter(x, y, color="red")

plt.plot(x, model.predict(x), color="blue")

plt.scatter(years, predicted_salary, color="green", marker="x", s=100, label="Prediction")

plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary Prediction")
plt.legend()

# %%
model.score(x, y)
# Out:
# 0.9569566641435086
