# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("train.csv")
df.dropna(inplace=True)
X = np.array(df.x).reshape(-1, 1)
y = np.array(df.y)

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Plot the data points
plt.scatter(X, y, color='blue', label='Data')

# Plot the fitted regression line
plt.plot(X, model.predict(X), color='red', label='Linear Regression')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
df_test = pd.read_csv("test.csv")

# %%
x_test = np.array(df_test.x).reshape(-1, 1)
y_test = np.array(df_test.y)

# %%
# Plot the data points
plt.scatter(X, y, color='blue', label='Train')

# Plot the fitted regression line
plt.plot(X, model.predict(X), color='red', label='Linear Regression')

plt.scatter(x_test, y_test, color='green', label='Test')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
prediction = model.predict(x_test)
r2 = r2_score(y_test, prediction)

# %%
error = []
for i in range(len(x_test)):
    p = y_pred[i]
    error.append(abs(y_test[i] - p))
    print(f"X: {x_test[i]}, Original: {y_test[i]}, Predicted: {p}, Error Set: {error[-1]}")
# Out:
# X: [77], Original: 79.77515201, Predicted: 76.94327593863443, Error Set: 2.8318760713655706
# X: [21], Original: 23.17727887, Predicted: 20.90651855468142, Error Set: 2.2707603153185794
# X: [22], Original: 25.60926156, Predicted: 21.90717493653772, Error Set: 3.7020866234622787
# X: [20], Original: 17.85738813, Predicted: 19.905862172825117, Error Set: 2.0484740428251165
# X: [36], Original: 41.84986439, Predicted: 35.916364282525976, Error Set: 5.933500107474025
# X: [15], Original: 9.805234876, Predicted: 14.902580263543596, Error Set: 5.097345387543596
# X: [62], Original: 58.87465933, Predicted: 61.93343021078987, Error Set: 3.058770880789872
# X: [95], Original: 97.61793701, Predicted: 94.9550908120479, Error Set: 2.6628461979521063
# X: [20], Original: 18.39512747, Predicted: 19.905862172825117, Error Set: 1.5107347028251183
# X: [5], Original: 8.746747654, Predicted: 4.89601644498056, Error Set: 3.8507312090194397
# ...

# %%
error = np.mean(error)

# %%
for i in range(len(x_test)):
    p = prediction[i] + error
    #e = abs(y_test[i] - p)
    print(f"X: {x_test[i]}, Original: {y_test[i]}, Predicted: {p}, Error: {abs(y_test[i] - p)}")
# Out:
# X: [77], Original: 79.77515201, Predicted: 79.35904778867568, Error: 0.4161042213243178
# X: [21], Original: 23.17727887, Predicted: 23.32229040472268, Error: 0.14501153472268058
# X: [22], Original: 25.60926156, Predicted: 24.32294678657898, Error: 1.2863147734210187
# X: [20], Original: 17.85738813, Predicted: 22.321634022866377, Error: 4.464245892866376
# X: [36], Original: 41.84986439, Predicted: 38.332136132567236, Error: 3.517728257432765
# X: [15], Original: 9.805234876, Predicted: 17.318352113584854, Error: 7.513117237584854
# X: [62], Original: 58.87465933, Predicted: 64.34920206083113, Error: 5.474542730831132
# X: [95], Original: 97.61793701, Predicted: 97.37086266208915, Error: 0.24707434791085348
# X: [20], Original: 18.39512747, Predicted: 22.321634022866377, Error: 3.9265065528663783
# X: [5], Original: 8.746747654, Predicted: 7.3117882950218185, Error: 1.4349593589781815
# X: [4], Original: 2.811415826, Predicted: 6.311131913165514, Error: 3.499716087165514
# ...
